# %%
import numpy as np
from utils.transformations import *

# %%
import numpy as np
p = np.array([100,110,100,120,80,90,130,120,110,150])
t = np.arange(len(p))
X = np.array(list(zip(t,p)))
leadlag(X)
# Out:
# [(100, 100),
#  (110, 100),
#  (110, 110),
#  (100, 110),
#  (100, 100),
#  (120, 100),
#  (120, 120),
#  (80, 120),
#  (80, 80),
#  (90, 80),
#  (90, 90),
#  (130, 90),
#  (130, 130),
#  (120, 130),
#  (120, 120),
#  (110, 120),
#  (110, 110),
#  (150, 110),
#  (150, 150)]

# %%
plotLeadLag(leadlag(X))

# %%
timejoined(list(X))
# Out:
# [(0, 0),
#  (0, 100),
#  (1, 100),
#  (1, 110),
#  (2, 110),
#  (2, 100),
#  (3, 100),
#  (3, 120),
#  (4, 120),
#  (4, 80),
#  (5, 80),
#  (5, 90),
#  (6, 90),
#  (6, 130),
#  (7, 130),
#  (7, 120),
#  (8, 120),
#  (8, 110),
#  (9, 110),
#  (9, 150),
#  (9, 150)]

# %%
plottimejoined(timejoined(list(X)))
